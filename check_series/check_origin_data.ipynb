# %%
import os
import json
rsitmd_path = '/home/dhm04/PycharmProjects/RSCR-baseline/dataset/RSITMD/dataset_RSITMD.json'
with open(rsitmd_path, 'r') as f:
    data = json.load(f)

# %%
import pdb

for item in data['images']:
    if item['split'] == 'test':
        print(len(item['sentids']))
# Out:
# 5
# > /tmp/ipykernel_81638/3944606931.py(3)<module>()
#       1 import pdb
#       2
# ----> 3 for item in data['images']:
#       4     if item['split'] == 'test':
#       5         print(len(item['sentids']))
#
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user
# 5
# > /tmp/ipykernel_81638/3944606931.py(3)<module>()
#       1 import pdb
#       2
# ----> 3 for item in data['images']:
#       4     if item['split'] == 'test':
#       5         print(len(item['sentids']))
#
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user
# 5
# > /tmp/ipykernel_81638/3944606931.py(3)<module>()
#       1 import pdb
#       2
# ----> 3 for item in data['images']:
#       4     if item['split'] == 'test':
#       5         print(len(item['sentids']))
#
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user
# 5
# > /tmp/ipykernel_81638/3944606931.py(3)<module>()
#       1 import pdb
#       2
# ----> 3 for item in data['images']:
# ...
